# %%
import sys
sys.path.insert(0, '/das/work/p17/p17983/')

# %%
# %matplotlib nbagg
import numpy as np
import json
import os
from matplotlib import pyplot as plt
from scipy.optimize import curve_fit

from alvra_tools.load_data import *
from alvra_tools.channels import *
from alvra_tools.utils import errfunc_sigma, errfunc_fwhm
from built_functions import *
# Out:
# [INFO][corrections] Numba not available, reverting to Numpy

# %% [markdown]
# Set up the filters.  "numstds" is the number of standard deviations to take from the median.

# %% [markdown]
# Plot some diagnostics

# %%
def get_XAS(scan_name, DIR, DIR_json, numstds, minIzero, lin_filter):


    json_file = DIR_json + scan_name + "_scan_info.json"
    print (json_file)

    with open(json_file) as file:
        data = json.load(file)
    numFiles = len(data['scan_files'])

    Energy_eV = np.empty(0)
    iZero = np.empty(0)
    
    err_DataFluo_pump_total = np.empty(0)
    err_DataFluo_unpump_total = np.empty(0)

    
    DataFluo_pump_norm_total = np.empty(0)
    DataFluo_unpump_norm_total = np.empty(0)

    IzeroFEL_pump_original_total = np.empty(0)
    IzeroFEL_unpump_original_total = np.empty(0)    
    DataFluo_pump_original_total = np.empty(0)
    DataFluo_unpump_original_total = np.empty(0)
    
    IzeroFEL_pump_total = np.empty(0)
    IzeroFEL_unpump_total = np.empty(0)
    DataFluo_pump_total = np.empty(0)
    DataFluo_unpump_total = np.empty(0)
    
    for i in range(0,numFiles):
        filename = str(data['scan_files'][i][0])
        filename = DIR + os.path.basename(filename)
        exists = os.path.isfile(filename)
        if not exists:
            print("No such file")
        elif exists:
            (DataFluo_pump, DataFluo_unpump, IzeroFEL_pump, IzeroFEL_unpump, Energy, _, _, _) = \
                load_PumpProbe_events(filename, channel_energy)

            IzeroFEL_pump_original = IzeroFEL_pump.copy()
            IzeroFEL_unpump_original = IzeroFEL_unpump.copy()

            IzeroFEL_pump_original_total = np.append(IzeroFEL_pump_original_total, IzeroFEL_pump_original)
            IzeroFEL_unpump_original_total = np.append(IzeroFEL_unpump_original_total, IzeroFEL_unpump_original)

            DataFluo_pump_original_total = np.append(DataFluo_pump_original_total, DataFluo_pump)
            DataFluo_unpump_original_total = np.append(DataFluo_unpump_original_total, DataFluo_unpump)
            
            # filter
            IzeroFEL_pump, IzeroFEL_unpump, DataFluo_pump, DataFluo_unpump, condFinalPump, condFinalUnPump\
                =filterData(IzeroFEL_pump, IzeroFEL_unpump, DataFluo_pump, DataFluo_unpump, numstds, minIzero, lin_filter)    

            DataFluo_pump_norm = DataFluo_pump/IzeroFEL_pump
            DataFluo_unpump_norm = DataFluo_unpump/IzeroFEL_unpump

            DataFluo_pump_norm_total = np.append(DataFluo_pump_norm_total, DataFluo_pump_norm.mean())
            DataFluo_unpump_norm_total = np.append(DataFluo_unpump_norm_total, DataFluo_unpump_norm.mean())
            
            err_DataFluo_pump_total = \
                np.append(err_DataFluo_pump_total, np.std(DataFluo_pump_norm))#/np.sqrt(DataFluo_pump_norm.shape[0]))
            err_DataFluo_unpump_total = \
                np.append(err_DataFluo_unpump_total, np.std(DataFluo_unpump_norm))#/np.sqrt(DataFluo_unpump_norm.shape[0]))
            
            IzeroFEL_pump_total = np.append(IzeroFEL_pump_total, IzeroFEL_pump)
            IzeroFEL_unpump_total = np.append(IzeroFEL_unpump_total, IzeroFEL_unpump)
            
            Energy = [x for x in Energy if (np.abs(x) > 0)]
            Energy_eV = np.append(Energy_eV, np.mean(Energy))
            
            iZero = [x for x in iZero if (np.abs(x) > 0)]
            iZero = np.append(iZero, np.mean(IzeroFEL_pump_total))

    return iZero, Energy_eV, IzeroFEL_pump_total, IzeroFEL_unpump_total,\
            DataFluo_pump_norm_total, DataFluo_unpump_norm_total, err_DataFluo_pump_total, err_DataFluo_unpump_total

# %%
def average_scans(basename, scanlist, DIR_root, DIR_json, numstds, minIzero, lin_filter):

    DataFluo_pump_norm_total_scans = np.empty(0)
    DataFluo_unpump_norm_total_scans = np.empty(0) 
    DataFluo_pump_norm_total_std = np.empty(0)
    DataFluo_unpump_norm_total_std = np.empty(0)     

    for jj in range(0, len(scanlist)):
        if scanlist[jj] < 10:
            scan_name = basename + '00' + str(scanlist[jj])
        else:
            scan_name = basename + '0' + str(scanlist[jj])

        DIR = DIR_root + scan_name + "/"

        print(scan_name)
        print(DIR)

        iZero, Energy_eV, IzeroFEL_pump_total, IzeroFEL_unpump_total,\
        DataFluo_pump_norm_total, DataFluo_unpump_norm_total, err_DataFluo_pump_total, err_DataFluo_unpump_total = \
            get_XAS(scan_name, DIR, DIR_json, numstds, minIzero, lin_filter)

        Energy_eV = Energy_eV[1:]
        DataFluo_pump_norm_total = DataFluo_pump_norm_total[1:]
        DataFluo_unpump_norm_total = DataFluo_unpump_norm_total[1:]
        err_DataFluo_pump_total = err_DataFluo_pump_total[1:]
        err_DataFluo_unpump_total = err_DataFluo_unpump_total[1:]
        iZero =iZero[1:]

        DataFluo_pump_norm_total_scans = np.append(DataFluo_pump_norm_total_scans, DataFluo_pump_norm_total)
        DataFluo_unpump_norm_total_scans = np.append(DataFluo_unpump_norm_total_scans, DataFluo_unpump_norm_total) 
        
        DataFluo_pump_norm_total_std = np.append(DataFluo_pump_norm_total_std, np.square(err_DataFluo_pump_total))
        DataFluo_unpump_norm_total_std = np.append(DataFluo_unpump_norm_total_std, np.square(err_DataFluo_unpump_total))

        print(DataFluo_pump_norm_total_scans.shape)
        
    n1 = len(scanlist)
    print(len(scanlist))
    n2 = int(DataFluo_pump_norm_total_scans.shape[0]/n1)
    
    print(DataFluo_pump_norm_total_scans.shape)
    print(DataFluo_pump_norm_total_std.shape)

    DataFluo_pump_norm_total_scans = np.reshape(DataFluo_pump_norm_total_scans, (n1, n2))
    DataFluo_unpump_norm_total_scans = np.reshape(DataFluo_unpump_norm_total_scans, (n1, n2))
    DataFluo_pump_norm_total_std = np.reshape(DataFluo_pump_norm_total_std, (n1, n2))
    DataFluo_unpump_norm_total_std = np.reshape(DataFluo_unpump_norm_total_std, (n1, n2))
                                                 
    print(DataFluo_pump_norm_total_scans.shape)

    DataFluo_pump_norm_total_ave = DataFluo_pump_norm_total_scans.mean(axis=0)   
    DataFluo_unpump_norm_total_ave = DataFluo_unpump_norm_total_scans.mean(axis=0)
    DataFluo_pump_norm_total_std = \
        np.sqrt(DataFluo_pump_norm_total_std.sum(axis=0))/np.sqrt(DataFluo_pump_norm_total_std.shape[0])
    DataFluo_unpump_norm_total_std = \
        np.sqrt(DataFluo_unpump_norm_total_std.sum(axis=0))/np.sqrt(DataFluo_unpump_norm_total_std.shape[0])                                                 

    DataFluo_diff_ave = DataFluo_pump_norm_total_ave - DataFluo_unpump_norm_total_ave
    DataFluo_diff_std = np.sqrt(np.square(DataFluo_pump_norm_total_std) + np.square(DataFluo_unpump_norm_total_std))

    p = DataFluo_pump_norm_total_ave
    u = DataFluo_unpump_norm_total_ave

    p_std = DataFluo_pump_norm_total_std
    u_std = DataFluo_unpump_norm_total_std

    d = DataFluo_diff_ave
    d_std = DataFluo_diff_std

    return scan_name, Energy_eV, p, u, p_std, u_std, d, d_std

# %%
DIR_root = "/sf/alvra/data/p17983/raw/scan_data/"
DIR_json = "/sf/alvra/data/p17983/res/scan_info/"


numstds = 3
minIzero = 0.015
lin_filter = 0.1

label_1 = 'Horz pol, scan #9, '
#basename_1 = 'RuDimerACN_monoscan_10ps_'
basename_1 = 'RuDimerACN_monoscan_0p6ps_'
scanlist_1 = [9]

label_2 = 'Vert pol, scan #10, '
basename_2 = 'RuDimerACN_monoscan_0p6ps_'
scanlist_2 = [10]


scan_name_1, Energy_eV_1, p_1, u_1, p_std_1, u_std_1, d_1, d_std_1 = \
    average_scans(basename_1, scanlist_1, DIR_root, DIR_json, numstds, minIzero, lin_filter)
scan_name_2, Energy_eV_2, p_2, u_2, p_std_2, u_std_2, d_2, d_std_2 = \
    average_scans(basename_2, scanlist_2, DIR_root, DIR_json, numstds, minIzero, lin_filter)
# Out:
# RuDimerACN_monoscan_0p6ps_009
# /sf/alvra/data/p17983/raw/scan_data/RuDimerACN_monoscan_0p6ps_009/
# /sf/alvra/data/p17983/res/scan_info/RuDimerACN_monoscan_0p6ps_009_scan_info.json
# (54,)
# 1
# (54,)
# (54,)
# (1, 54)
# RuDimerACN_monoscan_0p6ps_010
# /sf/alvra/data/p17983/raw/scan_data/RuDimerACN_monoscan_0p6ps_010/
# /sf/alvra/data/p17983/res/scan_info/RuDimerACN_monoscan_0p6ps_010_scan_info.json
# (54,)
# RuDimerACN_monoscan_0p6ps_011
# /sf/alvra/data/p17983/raw/scan_data/RuDimerACN_monoscan_0p6ps_011/
# /sf/alvra/data/p17983/res/scan_info/RuDimerACN_monoscan_0p6ps_011_scan_info.json
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-ba17b4492153> in <module>
#      20     average_scans(basename_1, scanlist_1, DIR_root, DIR_json, numstds, minIzero, lin_filter)
#      21 scan_name_2, Energy_eV_2, p_2, u_2, p_std_2, u_std_2, d_2, d_std_2 = \
# ---> 22     average_scans(basename_2, scanlist_2, DIR_root, DIR_json, numstds, minIzero, lin_filter)
#
# <ipython-input-4-5e1482665990> in average_scans(basename, scanlist, DIR_root, DIR_json, numstds, minIzero, lin_filter)
#      19         iZero, Energy_eV, IzeroFEL_pump_total, IzeroFEL_unpump_total,\
#      20         DataFluo_pump_norm_total, DataFluo_unpump_norm_total, err_DataFluo_pump_total, err_DataFluo_unpump_total = \
# ---> 21             get_XAS(scan_name, DIR, DIR_json, numstds, minIzero, lin_filter)
#      22
#      23         Energy_eV = Energy_eV[1:]
#
# <ipython-input-3-a87ffae38602> in get_XAS(scan_name, DIR, DIR_json, numstds, minIzero, lin_filter)
#      37         elif exists:
#      38             (DataFluo_pump, DataFluo_unpump, IzeroFEL_pump, IzeroFEL_unpump, Energy, _, _, _) = \
# ---> 39                 load_PumpProbe_events(filename, channel_energy)
#      40
#      41             IzeroFEL_pump_original = IzeroFEL_pump.copy()
#
# /das/work/p17/p17983/alvra_tools/load_data.py in load_PumpProbe_events(filename, channel_variable, nshots)
#     311
#     312 def load_PumpProbe_events(filename, channel_variable, nshots=None):
# --> 313     with h5py.File(filename, 'r') as BS_file:
#     314
#     315         BS_file = _get_data(BS_file)
#
# /sf/alvra/anaconda/dev/lib/python3.6/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     392                 fid = make_fid(name, mode, userblock_size,
#     393                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 394                                swmr=swmr)
#     395
#     396             if swmr_support:
#
# /sf/alvra/anaconda/dev/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     168         if swmr and swmr_support:
#     169             flags |= h5f.ACC_SWMR_READ
# --> 170         fid = h5f.open(name, flags, fapl=fapl)
#     171     elif mode == 'r+':
#     172         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (file signature not found)

# %%
plt.figure()
plt.plot(Energy_eV_1, u_1, label = label_1 + basename_1)
#plt.fill_between(Energy_eV_1, u_1 - u_std_1, u_1 + u_std_1, alpha = 0.2)
plt.plot(Energy_eV_2, u_2, label = label_2 + basename_2)
#plt.fill_between(Energy_eV_2, u_2 - u_std_2, u_2 + u_std_2, alpha = 0.2)
plt.grid()
plt.xlabel('energy (eV)')
plt.ylabel('absorption')
plt.legend()
plt.title('XAS Unpumped')

plt.figure()
plt.plot(Energy_eV_1, p_1, label = label_1 + basename_1)
#plt.fill_between(Energy_eV_1, p_1 - p_std_1, p_1 + p_std_1, alpha = 0.2)
plt.plot(Energy_eV_2, p_2, label = label_2 + basename_2)
#plt.fill_between(Energy_eV_2, p_2 - p_std_2, p_2 + p_std_2, alpha = 0.2)
plt.grid()
plt.xlabel('energy (eV)')
plt.ylabel('absorption')
plt.legend()
plt.title('XAS Pumped')

plt.figure()
plt.plot(Energy_eV_1, d_1, label = label_1 + basename_1)
#plt.fill_between(Energy_eV_1, d_1 - d_std_1, d_1 + d_std_1, alpha = 0.2)
plt.plot(Energy_eV_2, d_2, label = label_2 + basename_2)
#plt.fill_between(Energy_eV_2, d_2 - d_std_2, d_2 + d_std_2, alpha = 0.2)
plt.grid()
plt.xlabel('energy (eV)')
plt.ylabel('absorption')
plt.legend()
plt.title('XAS Difference')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'XAS Difference')
