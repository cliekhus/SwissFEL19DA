# %%
import sys
sys.path.insert(0, '/das/work/p17/p17983/')

# %%
# %matplotlib nbagg
import jungfrau_utils as ju
import numpy as np
import json
import os
import time
from matplotlib import pyplot as plt
from scipy.optimize import curve_fit

import h5py

from alvra_tools.load_data import *
from alvra_tools.channels import *
from built_functions import *
# Out:
# [INFO][corrections] Numba not available, reverting to Numpy

# %%
def get_xes_pumped(filename, DIR, DIRBS, roi, channel, ynstamp):
    numstds = 2.5
    minIzero = 0.01
    lin_filter = 0.2
    image_threshold = 2
    hot_pixel = 6

    print(DIR + filename + ".JF02T09V02crop.h5")
    print()
    print(DIRBS + filename + ".BSREAD.h5")
    
    images_off, images_on, pulse_ids_off, pulse_ids_on = \
        load_JF_cropped_data_pump(DIR + filename + ".JF02T09V02crop.h5", roi, 50, 50/2, nshots=None)
    (DataFluo_pump, DataFluo_unpump, IzeroFEL_pump, IzeroFEL_unpump, JFIDs_pump, JFIDs_unpump, Energy_pump, Energy_unpump, _, _) = \
        load_PumpProbe_events_withTwoVariables(DIRBS + filename + ".BSREAD.h5", channel_BS_pulse_ids, channel)
    (_, _, _, _, _, _, Laser_pump, Laser_unpump, _, _) = \
        load_PumpProbe_events_withTwoVariables(DIRBS + filename + ".BSREAD.h5", channel_PIPS_fluo, channel)
    
    Energy_pump = [x for x in Energy_pump if (np.abs(x) > 0)]
    Energy_eV_pump = np.mean(Energy_pump)
    
    Energy_unpump = [x for x in Energy_unpump if (np.abs(x) > 0)]
    Energy_eV_unpump = np.mean(Energy_unpump)
    
    idcheck = [a==b and c==d for a,b,c,d in zip(pulse_ids_on, JFIDs_pump, pulse_ids_off, JFIDs_unpump)]
    IDCheck = sum([int(x) for x in idcheck])
    
    if IDCheck:
        print("passed ID check")
    else:
        print("failed ID check")   
    
    IzeroMedian = np.median(np.concatenate([IzeroFEL_pump, IzeroFEL_unpump]))
    IzeroSTD = np.std(np.concatenate([IzeroFEL_pump, IzeroFEL_unpump]))
    
#     print('numon')
#     print(IzeroFEL_pump.shape[0])
    
#     print('numoff')
#     print(IzeroFEL_unpump.shape[0])
    
    print('number of frames')
    print(images_on.shape[0])
    print(images_off.shape[0])

    images_good_on = images_on
    images_good_off = images_off

    images_thr_on = images_good_on.copy()
    images_thr_on[images_good_on < image_threshold] = 0
    images_thr_on[images_good_on > hot_pixel] = 0
    images_thr_on[np.isnan(images_thr_on)] = 0
    
    images_thr_off = images_good_off.copy()
    images_thr_off[images_good_off < image_threshold] = 0
    images_thr_off[images_good_off > hot_pixel] = 0
    images_thr_off[np.isnan(images_thr_off)] = 0
    
#     print('num nan')
#     print(sum(sum(sum(np.isnan(images_thr_on)))))
    
#     print('Izero')
#     print(np.mean(IzeroFEL_unpump))
#     print(np.mean(IzeroFEL_pump))
#     print(np.max(IzeroFEL_unpump))
#     print(np.min(IzeroFEL_unpump))
    
    IzeroFEL_pump, IzeroFEL_unpump, DataFluo_pump, DataFluo_unpump, condFinalPump, condFinalUnPump = \
        filterData(IzeroFEL_pump, IzeroFEL_unpump, DataFluo_pump, DataFluo_unpump, numstds, minIzero, lin_filter)
    

    
#     print(images_thr_on.shape)
#     print(images_thr_on.shape)
    
    images_thr_on = images_thr_on[condFinalPump]
    images_thr_off = images_thr_off[condFinalUnPump]

#     print('number of surviving frames')
#     print(images_thr_on.shape[0])
#     print(images_thr_off.shape[0])
    
    XES_on = images_thr_on.sum(axis=0)/images_thr_on.shape[0]
    XES_off = images_thr_off.sum(axis=0)/images_thr_off.shape[0]
    
    XES_on[np.isnan(XES_on)] = 0
    XES_off[np.isnan(XES_off)] = 0
    
#     print('num nan')
#     print(sum(sum(np.isnan(XES_on))))
    
    stamp = make_bar_stamp(XES_on.shape[1],XES_on.shape[0])
    
#     print(XES_on.shape)
#     print(stamp.shape)
    if ynstamp:

        XES_on = XES_on * stamp
        XES_off = XES_off * stamp
        
    FloFEL_pump_total = np.mean(DataFluo_pump)/np.mean(IzeroFEL_pump)
    FloFEL_unpump_total = np.mean(DataFluo_unpump)/np.mean(IzeroFEL_unpump)
    
    return XES_on, XES_off, Energy_eV_pump, Energy_eV_unpump, FloFEL_pump_total, FloFEL_unpump_total

# %%
def make_bar_stamp(dimension_x, dimension_y):

    X,Y = np.meshgrid(np.linspace(0,dimension_x-1,dimension_x),np.linspace(0,dimension_y-1,dimension_y))

    Z = np.zeros([dimension_y,dimension_x])+1

    condition = np.logical_and(Y<260, Y>253)
    Z[condition] = 0
    
    Z[Y>320] = 0
    Z[Y < 200] = 0

    condition = np.logical_not(np.logical_and(X<230, X>130))
    Z[condition] = 0

    #plt.figure()
    #plt.imshow(Z)
    
    #plt.colorbar()
    
    return Z

# %%
run_list_01_a = np.linspace(501,547,547-501+1)
run_list_01_b = np.linspace(619,677,677-619+1)

run_list_01_a = np.arange(501,547+1)
run_list_01_b = np.arange(619,677+1)
run_list_01 = np.concatenate((run_list_01_a,run_list_01_b), axis = None)
print(run_list_01)
# Out:
# [501 502 503 504 505 506 507 508 509 510 511 512 513 514 515 516 517 518
#  519 520 521 522 523 524 525 526 527 528 529 530 531 532 533 534 535 536
#  537 538 539 540 541 542 543 544 545 546 547 619 620 621 622 623 624 625
#  626 627 628 629 630 631 632 633 634 635 636 637 638 639 640 641 642 643
#  644 645 646 647 648 649 650 651 652 653 654 655 656 657 658 659 660 661
#  662 663 664 665 666 667 668 669 670 671 672 673 674 675 676 677]

# %% [markdown]
# Run for RIXS

# %%
ynCompare12 = 'yes'
#normalize = False

# folder_name_01 = 'XES_2836.5eV_600fs'
# folder_name_01 = 'XES_2842.0eV_10ps'
# folder_name_01 = 'XES_2836.5eV_600fs'
# folder_name_01 = 'XES_2842.0eV_10ps'
# folder_name_01 = 'XES_RuDimerCl_2842.0eV_600fs'
folder_name_01 = 'XES_RuDimerCl_2837.0eV_600fs'


run_list_01 = np.arange(678,760+1)
# run_list_01_b = np.arange(619,677+1)
# run_list_01 = np.concatenate((run_list_01_a,run_list_01_b), axis = None)
print(run_list_01)
run_list_01 = [int(x) for x in run_list_01]






# folder_name_02 = 'XES_2836.5eV_10ps'
# folder_name_02 = 'XES_2842.0eV_600fs'
# folder_name_02 = 'XES_RuDimerCl_2842.0eV_10ps
folder_name_02 = 'XES_RuDimerCl_2837.0eV_10ps'


run_list_02 = np.arange(761,842+1)

# run_list_02_b = np.arange(619,677+1)
# run_list_02 = np.concatenate((run_list_02_a,run_list_02_b), axis = None)
run_list_02 = [int(x) for x in run_list_02]
print(run_list_02)







run_list = run_list_01
folder_name = folder_name_01

filename_base = "run_"

DIR = "/das/work/p17/p17983/cropped_data/" + folder_name + "/"
DIRBS = "/sf/alvra/data/p17983/raw/" + folder_name + "/"


iterCounter = 0

for ii in run_list:


    XES_on, XES_off, Energy_eV_pump, Energy_eV_unpump, fluo_pump, fluo_unpump = \
        get_xes_pumped(filename_base + '%06d' % (ii), DIR, DIRBS, 2, channel_energy, True)

    
        
    if False:

        plt.figure()
        plt.subplot(1,2,1)
        plt.title('ON')
        plt.imshow(XES_on, vmax = 0.001)
        plt.colorbar()
        plt.subplot(1,2,2)
        plt.title('OFF')
        plt.imshow(XES_off, vmax = 0.001)
        plt.colorbar()
        plt.tight_layout()

    
    if iterCounter == 0:
        rixs_on = XES_on.sum(axis=0)
        rixs_off = XES_off.sum(axis=0)
    else:
        rixs_on = np.vstack((rixs_on,XES_on.sum(axis=0)))
        rixs_off = np.vstack((rixs_off,XES_off.sum(axis=0)))

    
    
    iterCounter +=1

    
xAxis = np.linspace(1,XES_on.shape[1],XES_on.shape[1])
 
if len(run_list) == 1:
    RIXS_on_01 = rixs_on
    RIXS_off_01 = rixs_off
else:
    RIXS_on_01 = rixs_on.sum(axis=0)
    RIXS_off_01 = rixs_off.sum(axis=0)
    
err_on_01 = np.std(rixs_on, axis = 0)/np.sqrt(rixs_on.shape[0]-1)
err_off_01 = np.std(rixs_off, axis = 0)/np.sqrt(rixs_off.shape[0]-1)
# Out:
# [678 679 680 681 682 683 684 685 686 687 688 689 690 691 692 693 694 695
#  696 697 698 699 700 701 702 703 704 705 706 707 708 709 710 711 712 713
#  714 715 716 717 718 719 720 721 722 723 724 725 726 727 728 729 730 731
#  732 733 734 735 736 737 738 739 740 741 742 743 744 745 746 747 748 749
#  750 751 752 753 754 755 756 757 758 759 760]
# [761, 762, 763, 764, 765, 766, 767, 768, 769, 770, 771, 772, 773, 774, 775, 776, 777, 778, 779, 780, 781, 782, 783, 784, 785, 786, 787, 788, 789, 790, 791, 792, 793, 794, 795, 796, 797, 798, 799, 800, 801, 802, 803, 804, 805, 806, 807, 808, 809, 810, 811, 812, 813, 814, 815, 816, 817, 818, 819, 820, 821, 822, 823, 824, 825, 826, 827, 828, 829, 830, 831, 832, 833, 834, 835, 836, 837, 838, 839, 840, 841, 842]
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000678.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000678.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000679.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000679.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000680.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000680.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000681.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000681.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000682.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000682.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000683.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000683.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000684.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000684.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000685.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000685.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000686.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000686.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000687.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000687.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000688.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000688.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000689.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000689.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000690.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000690.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000691.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000691.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000692.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000692.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /sf/alvra/anaconda/dev/lib/python3.6/site-packages/ipykernel/__main__.py:83: RuntimeWarning: invalid value encountered in true_divide
# /sf/alvra/anaconda/dev/lib/python3.6/site-packages/ipykernel/__main__.py:84: RuntimeWarning: invalid value encountered in true_divide
# /sf/alvra/anaconda/dev/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /sf/alvra/anaconda/dev/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000693.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000693.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000694.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000694.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000695.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000695.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000696.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000696.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000697.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000697.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000698.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000698.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000699.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000699.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000700.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000700.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000701.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000701.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000702.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000702.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000703.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000703.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000704.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000704.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000705.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000705.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000706.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000706.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000707.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000707.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000708.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000708.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000709.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000709.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000710.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000710.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000711.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000711.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000712.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000712.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000713.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000713.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000714.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000714.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000715.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000715.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000716.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000716.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000717.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000717.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000718.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000718.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000719.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000719.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000720.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000720.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000721.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000721.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000722.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000722.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000723.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000723.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000724.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000724.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000725.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000725.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000726.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000726.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000727.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000727.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000728.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000728.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000729.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000729.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000730.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000730.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000731.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000731.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000732.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000732.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000733.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000733.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000734.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000734.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000735.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000735.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000736.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000736.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000737.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000737.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000738.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000738.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000739.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000739.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000740.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000740.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000741.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000741.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000742.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000742.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000743.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000743.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000744.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000744.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000745.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000745.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000746.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000746.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000747.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000747.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000748.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000748.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000749.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000749.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000750.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000750.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000751.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000751.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000752.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000752.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000753.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000753.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000754.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000754.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000755.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000755.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000756.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000756.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000757.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000757.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000758.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000758.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000759.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000759.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_600fs/run_000760.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_600fs/run_000760.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250

# %%
# run_list_02 = np.arange(441,460+1)
# # run_list_02_b = np.arange(619,677+1)
# # run_list_02 = np.concatenate((run_list_02_a,run_list_02_b), axis = None)
# run_list_02 = [int(x) for x in run_list_02]
# print(run_list_02)

# ynCompare12 = 'yes'
if ynCompare12 == 'yes':

    folder_name = folder_name_02
    run_list = run_list_02
    DIR = "/das/work/p17/p17983/cropped_data/" + folder_name + "/"
    DIRBS = "/sf/alvra/data/p17983/raw/" + folder_name + "/"

    iterCounter = 0

    for ii in run_list:

        XES_on, XES_off, Energy_eV_pump, Energy_eV_unpump, fluo_pump, fluo_unpump = \
            get_xes_pumped(filename_base + '%06d' % (ii), DIR, DIRBS, 2, channel_energy, True)

        if False:

            plt.figure()
            plt.subplot(1,2,1)
            plt.title('ON')
            plt.imshow(XES_on, vmax = 0.001)
            plt.colorbar()
            plt.subplot(1,2,2)
            plt.title('OFF')
            plt.imshow(XES_off, vmax = 0.001)
            plt.colorbar()
            plt.tight_layout()


        if iterCounter == 0:
            rixs_on = XES_on.sum(axis=0)
            rixs_off = XES_off.sum(axis=0)
        else:
            rixs_on = np.vstack((rixs_on,XES_on.sum(axis=0)))
            rixs_off = np.vstack((rixs_off,XES_off.sum(axis=0)))

        iterCounter +=1

    if len(run_list) == 1:
        RIXS_on_02 = rixs_on
        RIXS_off_02 = rixs_off
    else:
        RIXS_on_02 = rixs_on.sum(axis=0)
        RIXS_off_02 = rixs_off.sum(axis=0)
        
    err_on_02 = np.std(rixs_on, axis = 0)/np.sqrt(rixs_on.shape[0]-1)
    err_off_02 = np.std(rixs_off, axis = 0)/np.sqrt(rixs_off.shape[0]-1)
# Out:
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000761.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000761.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000762.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000762.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000763.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000763.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000764.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000764.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000765.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000765.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000766.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000766.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000767.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000767.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000768.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000768.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000769.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000769.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000770.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000770.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000771.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000771.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000772.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000772.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000773.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000773.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000774.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000774.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000775.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000775.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000776.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000776.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000777.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000777.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000778.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000778.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000779.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000779.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000780.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000780.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000781.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000781.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000782.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000782.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000783.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000783.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000784.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000784.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000785.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000785.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000786.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000786.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000787.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000787.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000788.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000788.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000789.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000789.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000790.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000790.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000791.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000791.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000792.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000792.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000793.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000793.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000794.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000794.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000795.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000795.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000796.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000796.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000797.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000797.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000798.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000798.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000799.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000799.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000800.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000800.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000801.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000801.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000802.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000802.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000803.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000803.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000804.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000804.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000805.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000805.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000806.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000806.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000807.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000807.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000808.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000808.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000809.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000809.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000810.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000810.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000811.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000811.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /sf/alvra/anaconda/dev/lib/python3.6/site-packages/ipykernel/__main__.py:83: RuntimeWarning: invalid value encountered in true_divide
# /sf/alvra/anaconda/dev/lib/python3.6/site-packages/ipykernel/__main__.py:84: RuntimeWarning: invalid value encountered in true_divide
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000812.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000812.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000813.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000813.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000814.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000814.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000815.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000815.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000816.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000816.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000817.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000817.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000818.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000818.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000819.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000819.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000820.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000820.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000821.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000821.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000822.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000822.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000823.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000823.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000824.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000824.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000825.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000825.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000826.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000826.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000827.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000827.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000828.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000828.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000829.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000829.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000830.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000830.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000831.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000831.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000832.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000832.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000833.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000833.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000834.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000834.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000835.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000835.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000836.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000836.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000837.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000837.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000838.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000838.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000839.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000839.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000840.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000840.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000841.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000841.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250
# /das/work/p17/p17983/cropped_data/XES_RuDimerCl_2837.0eV_10ps/run_000842.JF02T09V02crop.h5
#
# /sf/alvra/data/p17983/raw/XES_RuDimerCl_2837.0eV_10ps/run_000842.BSREAD.h5
# images_roi2
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# SLAAR11-LMOT-M451:ENC_1_BS/pulse_id
# passed ID check
# number of frames
# 1250
# 1250

# %%
normalize = False



RIXS_trans_01 = (RIXS_on_01-RIXS_off_01)
err_trans_01 = err_adder(err_on_01,err_off_01)
if normalize:
    RIXS_trans_01 = RIXS_trans_01/RIXS_off_01
    err_trans_01 = RIXS_trans_01/RIXS_off_01*err_adder(err_trans_01/RIXS_trans_01,err_off_01/RIXS_off_01)

    
xRange_01 = [140,220]

plt.figure()
plt.subplot(2,1,1)
plt.plot(xAxis,RIXS_trans_01)
plt.fill_between(xAxis,RIXS_trans_01+err_trans_01,RIXS_trans_01-err_trans_01,alpha = 0.2)
plt.xlabel('JF pixel')
plt.ylabel('Intensity (arb)')
plt.title('XES transient '+folder_name_01)
plt.xlim(xRange_01)

plt.subplot(2,1,2)
plt.plot(xAxis,RIXS_on_01, label ='XES ON')
plt.fill_between(xAxis,RIXS_on_01+err_on_01,RIXS_on_01-err_on_01, alpha = 0.2)
plt.plot(xAxis,RIXS_off_01, label = 'XES OFF')
plt.fill_between(xAxis,RIXS_off_01+err_off_01,RIXS_off_01-err_off_01, alpha = 0.2)
plt.xlabel('JF pixel')
plt.ylabel('Intensity (arb)')
plt.title('XES ' +folder_name_01)
plt.xlim(xRange_01)
plt.legend()

plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
if ynCompare12 == 'yes':
    RIXS_trans_02 = (RIXS_on_02-RIXS_off_02)
    err_trans_02 = err_adder(err_on_02,err_off_02)
    if normalize:
        RIXS_trans_02 = RIXS_trans_02/RIXS_off_02
        err_trans_02 = RIXS_trans_02/RIXS_off_02*err_adder(err_trans_02/RIXS_trans_02,err_off_02/RIXS_off_02)


    xRange_02 = xRange_01

    plt.figure()
    plt.subplot(2,1,1)
    plt.plot(xAxis,RIXS_trans_02)
    plt.fill_between(xAxis,RIXS_trans_02+err_trans_02,RIXS_trans_02-err_trans_02,alpha = 0.2)
    plt.xlabel('JF pixel')
    plt.ylabel('Intensity (arb)')
    plt.title('XES transient '+folder_name_02)
    plt.xlim(xRange_02)

    plt.subplot(2,1,2)
    plt.plot(xAxis,RIXS_on_02, label ='XES ON')
    plt.fill_between(xAxis,RIXS_on_02+err_on_02,RIXS_on_02-err_on_02, alpha = 0.2)
    plt.plot(xAxis,RIXS_off_02, label = 'XES OFF')
    plt.fill_between(xAxis,RIXS_off_02+err_off_02,RIXS_off_02-err_off_02, alpha = 0.2)
    plt.xlabel('JF pixel')
    plt.ylabel('Intensity (arb)')
    plt.title('XES ' +folder_name_02)
    plt.xlim(xRange_02)
    plt.legend()

    plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
if ynCompare12 == 'yes':
    scale_01 = len(run_list_01)
    scale_02 = len(run_list_02)
    
    
    s_02 = 1.5
    
    plt.figure()        
    plt.plot(xAxis,s_02*RIXS_trans_01, label = folder_name_01)
    plt.fill_between(xAxis,RIXS_trans_01+err_trans_01,RIXS_trans_01-err_trans_01,alpha = 0.2)
    plt.plot(xAxis,RIXS_trans_02, label = folder_name_02)
    plt.fill_between(xAxis,s_02*(RIXS_trans_02+err_trans_02),s_02*(RIXS_trans_02-err_trans_02),alpha = 0.2)
    plt.xlabel('JF pixel')
    plt.ylabel('Intensity (arb)')
    plt.title('XES transient Comparison')
    plt.legend()
    plt.xlim(xRange_02)
    
    
    plt.figure()
    plt.plot(xAxis,RIXS_on_01/scale_01, label ='XES ON'+folder_name_01)
    plt.fill_between(xAxis,(RIXS_on_01+err_on_01)/scale_01,(RIXS_on_01-err_on_01)/scale_01, alpha = 0.2)
    plt.plot(xAxis,s_02*RIXS_on_02/scale_02, label ='XES ON'+folder_name_02)
    plt.fill_between(xAxis,s_02*(RIXS_on_02+err_on_02)/scale_02,s_02*(RIXS_on_02-err_on_02)/scale_02, alpha = 0.2)
    plt.xlabel('JF pixel')
    plt.ylabel('Intensity (arb)')
    plt.title('XES ON Comparison')
    plt.legend()
    plt.xlim(xRange_02)
    
    plt.figure()
    plt.plot(xAxis,RIXS_off_01/scale_01, label ='XES OFF'+folder_name_01)
    plt.fill_between(xAxis,(RIXS_off_01+err_off_01)/scale_01,(RIXS_off_01-err_off_01)/scale_01, alpha = 0.2)
    plt.plot(xAxis,s_02*RIXS_off_02/scale_02, label ='XES OFF'+folder_name_02)
    plt.fill_between(xAxis,s_02*(RIXS_off_02+err_off_02)/scale_02,s_02*(RIXS_off_02-err_off_02)/scale_02, alpha = 0.2)
    plt.xlabel('JF pixel')
    plt.ylabel('Intensity (arb)')
    plt.title('XES OFF Comparison')
    plt.legend()
    plt.xlim(xRange_02)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b7f6058262d3> in <module>
# ----> 1 if ynCompare12 == 'yes':
#       2     scale_01 = len(run_list_01)
#       3     scale_02 = len(run_list_02)
#       4
#       5
#
# NameError: name 'ynCompare12' is not defined

# %%
ynCompare12 = 'yes'

# %%
if True:
    scale_01 = len(run_list_01)
    scale_01 = scale_01*1/2
    red_data_file_01 = '/das/work/p17/p17983/Reduced_data/'+ folder_name_01

    np.save(red_data_file_01+'XES_on',RIXS_on_01/scale_01)
    np.save(red_data_file_01+'XES_on_err',err_on_01/scale_01)
    
    np.save(red_data_file_01+'XES_off',RIXS_off_01/scale_01)
    np.save(red_data_file_01+'XES_off_err',err_off_01/scale_01)
    
    np.save(red_data_file_01+'XES_trans',RIXS_trans_01)
    np.save(red_data_file_01+'XES_trans_err',err_trans_01)
    
if True:
    scale_02 = len(run_list_02)
    scale_02 = scale_02*1/2
    red_data_file_02 = '/das/work/p17/p17983/Reduced_data/'+ folder_name_02
    
    np.save(red_data_file_02+'XES_on',RIXS_on_02/scale_02)
    np.save(red_data_file_02+'XES_on_err',err_on_02/scale_02)
    
    np.save(red_data_file_02+'XES_off',RIXS_off_02/scale_02)
    np.save(red_data_file_02+'XES_off_err',err_off_02/scale_02)
    
    np.save(red_data_file_02+'XES_trans',RIXS_trans_02/scale_02)
    np.save(red_data_file_02+'XES_trans_err',err_trans_02/scale_02)
