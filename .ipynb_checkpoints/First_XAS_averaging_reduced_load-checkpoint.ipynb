# %%
import sys
sys.path.insert(0, '/das/work/p17/p17983/')

# %%
# %matplotlib nbagg
import numpy as np
import json
import os
from matplotlib import pyplot as plt
from scipy.optimize import curve_fit

from alvra_tools.load_data import *
from alvra_tools.channels import *
from alvra_tools.utils import errfunc_sigma, errfunc_fwhm
from built_functions import *
ploton = True
# Out:
# [INFO][corrections] Numba not available, reverting to Numpy

# %%
dirName_01 = '/das/work/p17/p17983/Reduced_data/XAS_ACN/10p/scans_7_9'


if not os.path.exists(dirName_01):
    print("Directory " , dirName_01 ,  " Does Not Exist ")

else:    
    print("Directory " , dirName_01 ,  " Directory found ")    

    Energy_eV_01 = np.load(dirName_01+'/Energy_eV.npy')
    
    avg_p_bg_01 = np.load(dirName_01+'/avgFluo_pump_bg.npy')
    DataFluo_pump_norm_total_01 = np.load(dirName_01+'/avgFluo_pump.npy')
    err_DataFluo_pump_total_01 = np.load(dirName_01+'/err_pump.npy')
    
    avg_u_bg_01 = np.load(dirName_01+'/avgFluo_unpump_bg.npy')
    DataFluo_unpump_norm_total_01 = np.load(dirName_01+'/avgFluo_unpump.npy')
    err_DataFluo_unpump_total_01 = np.load(dirName_01+'/err_unpump.npy')
    
    diff_01 = np.load(dirName_01+'/trans.npy')
    err_trans_01 = np.load(dirName_01+'/err_trans.npy')
    
    strList_01 = np.load(dirName_01+'/scanList.npy')
#     strList_01 = str(strList_01[0])
# Out:
# Directory  /das/work/p17/p17983/Reduced_data/XAS_ACN/10p/scans_7_9  Directory found

# %%
dirName_02 = '/das/work/p17/p17983/Reduced_data/XAS_ACN/10p/scans_7_9'
if True:
    if not os.path.exists(dirName_02):
        print("Directory " , dirName_02 ,  " Does Not Exist ")

    else:    
        print("Directory " , dirName_02 ,  " Directory found ")    

        Energy_eV_02 = np.load(dirName_02+'/Energy_eV.npy')

        avg_p_bg_02 = np.load(dirName_02+'/avgFluo_pump_bg.npy')
        DataFluo_pump_norm_total_02 = np.load(dirName_02+'/avgFluo_pump.npy')
        err_DataFluo_pump_total_02 = np.load(dirName_02+'/err_pump.npy')

        avg_u_bg_02 = np.load(dirName_02+'/avgFluo_unpump_bg.npy')
        DataFluo_unpump_norm_total_02 = np.load(dirName_02+'/avgFluo_unpump.npy')
        err_DataFluo_unpump_total_02 = np.load(dirName_02+'/err_unpump.npy')

        diff_02 = np.load(dirName_02+'/trans.npy')
        err_trans_02 = np.load(dirName_02+'/err_trans.npy')
        
        strList_02 = np.load(dirName_02+'/scanList.npy')
#         strList_02 = str(strList_02[0])
# Out:
# Directory  /das/work/p17/p17983/Reduced_data/XAS_ACN/10p/scans_7_9  Directory found

# %% [markdown]
# Set up the filters.  "numstds" is the number of standard deviations to take from the median.

# %% [markdown]
# Plot some diagnostics

# %%
ploton = True



#intial settings
# numstds = 3
# minIzero = 0.02
# lin_filter =0.1

numstds = 2
minIzero = 0.02
lin_filter = 0.1

plot_02 = 'yes'
colorP = 'blue'
colorUP = 'orange'

# %%
err_trans_high_01 = diff_01 + err_trans_01
err_trans_low_01 = diff_01 - err_trans_01

err_trans_high_02 = diff_02 + err_trans_02
err_trans_low_02 = diff_02 - err_trans_02

print(str)

plt.figure()
plt.plot(np.array(Energy_eV_01), diff_01, color = colorP, label='scans 01')
plt.fill_between(np.array(Energy_eV_01),err_trans_low_01,err_trans_high_01, alpha = 0.3, color = colorP)

if plot_02 == 'yes':
    plt.plot(np.array(Energy_eV_02), diff_02, color = colorUP, label='scans 02')
    plt.fill_between(np.array(Energy_eV_02),err_trans_low_02,err_trans_high_02, alpha = 0.2, color = colorUP)

plt.legend()
plt.title('XAS, (pumped - unpumped)/unpumped')
plt.ylabel('totally arb')
plt.xlabel('energy(ev)')
if Energy_eV_01.shape[0]>Energy_eV_02.shape[0]:
    zeroLine = np.zeros(np.array(Energy_eV_01).shape)
    plt.plot(np.array(Energy_eV_01),zeroLine)
else:
    zeroLine = np.zeros(np.array(Energy_eV_02).shape)
    plt.plot(np.array(Energy_eV_02),zeroLine)


###### Make the switch between transient and pump/unpump XAS ######


err_unpump_high_01 = avg_u_bg_01 + err_DataFluo_unpump_total_01
err_unpump_low_01= avg_u_bg_01 - err_DataFluo_unpump_total_01

err_pump_high_01 = avg_p_bg_01 + err_DataFluo_pump_total_01
err_pump_low_01 =  avg_p_bg_01- err_DataFluo_pump_total_01

err_unpump_high_02 = avg_u_bg_02 + err_DataFluo_unpump_total_02
err_unpump_low_02 = avg_u_bg_02 - err_DataFluo_unpump_total_02

err_pump_high_02 = avg_p_bg_02 + err_DataFluo_pump_total_02
err_pump_low_02 = avg_p_bg_02 - err_DataFluo_pump_total_02


plt.figure()
plt.plot(np.array(Energy_eV_01), avg_u_bg_01,color = colorUP , label='scans 01 unpumped') 
plt.fill_between(np.array(Energy_eV_01), err_unpump_high_01, err_unpump_low_01, alpha = 0.3, color = colorUP)
plt.plot(np.array(Energy_eV_01), avg_p_bg_01,color = colorP, label='scans_01 pumped')
plt.fill_between(np.array(Energy_eV_01), err_pump_high_01, err_pump_low_01, alpha = 0.3, color = colorP)
plt.legend()
plt.title('XAS (background subtracted)')
plt.ylabel('totally arb')
plt.xlabel('energy(ev)')




if plot_02 == 'yes':

    plt.figure()
    plt.plot(np.array(Energy_eV_02), avg_u_bg_02,color = colorUP , label='scans _02 unpumped') 
    plt.fill_between(np.array(Energy_eV_02), err_unpump_high_02, err_unpump_low_02, alpha = 0.3, color = colorUP)
    plt.plot(np.array(Energy_eV_02), avg_p_bg_02,color = colorP, label='scans _02 pumped')
    plt.fill_between(np.array(Energy_eV_02), err_pump_high_02, err_pump_low_02, alpha = 0.3, color = colorP)
    plt.legend()
    plt.title('XAS (background subtracted)')
    plt.ylabel('totally arb')
    plt.xlabel('energy(ev)')
# Out:
# <class 'str'>
# <img src="data:image/png;base64,..." width="639.85">
# <img src="data:image/png;base64,..." width="639.85">
# <img src="data:image/png;base64,..." width="639.85">

# %%
scale = 1

plt.figure()
plt.plot(np.array(Energy_eV_02), avg_p_bg_02/scale, label='scans _02 pumped')
# plt.fill_between(np.array(Energy_eV_02), err_pump_high_02, err_pump_low_02, alpha = 0.3)
plt.plot(np.array(Energy_eV_01), avg_p_bg_01, label='scans 01 pumped')
# plt.fill_between(np.array(Energy_eV_01), err_pump_high_01, err_pump_low_01, alpha = 0.3)
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="639.85">
