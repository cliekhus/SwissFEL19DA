# %%
import sys
sys.path.insert(0, '/das/work/p17/p17983/')

# %%
# %matplotlib nbagg
import jungfrau_utils as ju
import numpy as np
import json
import os
import time
from matplotlib import pyplot as plt
from scipy.optimize import curve_fit

import h5py

from alvra_tools.load_data import *
from alvra_tools.channels import *
# Out:
# [INFO][corrections] Numba not available, reverting to Numpy

# %%
scan_name = "Ru_foil_monoscan_001"
DIR = "/das/work/p17/p17983/cropped_data/scan_data/" + scan_name + "/"
DIRBS = "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/"
DIR_json = "/sf/alvra/data/p17983/res/scan_info/"

listfile = os.listdir(DIR)
number_files = len(listfile)
print ("There are",number_files,"files in the folder", DIR)
# Out:
# There are 21 files in the folder /das/work/p17/p17983/cropped_data/scan_data/Ru_foil_monoscan_001/

# %%
# !cat /sf/alvra/data/p17983/res/scan_info/Ru_foil_monoscan_001_scan_info.json
# Out:
# {
#     "scan_files": [
#         [
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0000.BSREAD.h5",
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0000.JF06T32V01.h5"
#         ],
#         [
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0001.BSREAD.h5",
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0001.JF06T32V01.h5"
#         ],
#         [
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0002.BSREAD.h5",
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0002.JF06T32V01.h5"
#         ],
#         [
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0003.BSREAD.h5",
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0003.JF06T32V01.h5"
#         ],
#         [
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0004.BSREAD.h5",
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0004.JF06T32V01.h5"
#         ],
#         [
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0005.BSREAD.h5",
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0005.JF06T32V01.h5"
#         ],
#         [
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0006.BSREAD.h5",
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0006.JF06T32V01.h5"
#         ],
#         [
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0007.BSREAD.h5",
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0007.JF06T32V01.h5"
#         ],
#         [
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0008.BSREAD.h5",
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0008.JF06T32V01.h5"
#         ],
#         [
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0009.BSREAD.h5",
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0009.JF06T32V01.h5"
#         ],
#         [
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0010.BSREAD.h5",
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0010.JF06T32V01.h5"
#         ],
#         [
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0011.BSREAD.h5",
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0011.JF06T32V01.h5"
#         ],
#         [
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0012.BSREAD.h5",
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0012.JF06T32V01.h5"
#         ],
#         [
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0013.BSREAD.h5",
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0013.JF06T32V01.h5"
#         ],
#         [
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0014.BSREAD.h5",
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0014.JF06T32V01.h5"
#         ],
#         [
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0015.BSREAD.h5",
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0015.JF06T32V01.h5"
#         ],
#         [
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0016.BSREAD.h5",
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0016.JF06T32V01.h5"
#         ],
#         [
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0017.BSREAD.h5",
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0017.JF06T32V01.h5"
#         ],
#         [
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0018.BSREAD.h5",
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0018.JF06T32V01.h5"
#         ],
#         [
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0019.BSREAD.h5",
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0019.JF06T32V01.h5"
#         ],
#         [
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0020.BSREAD.h5",
#             "/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0020.JF06T32V01.h5"
#         ]
#     ],
#     "scan_parameters": {
#         "Id": [
#             "SAROP11-ODCM105"
#         ],
#         "name": [
#             "Alvra DCM monochromator coupled to FEL beam"
#         ]
#     },
#     "scan_readbacks": [
#         [
#             2829.9980614674514
#         ],
#         [
#             2831.005334940948
#         ],
#         [
#             2832.006736077957
#         ],
#         [
#             2833.007398877172
#         ],
#         [
#             2834.006202820259
#         ],
#         [
#             2835.006716018746
#         ],
#         [
#             2836.0079724399834
#         ],
#         [
#             2837.0059910823225
#         ],
#         [
#             2838.006215160743
#         ],
#         [
#             2839.003837111407
#         ],
#         [
#             2840.0050622949484
#         ],
#         [
#             2841.005752170101
#         ],
#         [
#             2842.0056780608747
#         ],
#         [
#             2843.0054867163203
#         ],
#         [
#             2844.0049503085434
#         ],
#         [
#             2845.0058473179533
#         ],
#         [
#             2846.005040754735
#         ],
#         [
#             2847.005439979926
#         ],
#         [
#             2848.0051844075156
#         ],
#         [
#             2849.005177134109
#         ],
#         [
#             2850.00513964378
#         ]
#     ],
#     "scan_step_info": [
#         null,
#         null,
#         null,
#         null,
#         null,
#         null,
#         null,
#         null,
#         null,
#         null,
#         null,
#         null,
#         null,
#         null,
#         null,
#         null,
#         null,
#         null,
#         null,
#         null,
#         null
#     ],
#     "scan_values": [
#         [
#             2830.0
#         ],
#         [
#             2831.0
#         ],
#         [
#             2832.0
#         ],
#         [
#             2833.0
#         ],
#         [
#             2834.0
#         ],
#         [
#             2835.0
#         ],
#         [
#             2836.0
#         ],
#         [
#             2837.0
#         ],
#         [
#             2838.0
#         ],
#         [
#             2839.0
#         ],
#         [
#             2840.0
#         ],
#         [
#             2841.0
#         ],
#         [
#             2842.0
#         ],
#         [
#             2843.0
#         ],
#         [
#             2844.0
#         ],
#         [
#             2845.0
#         ],
#         [
#             2846.0
#         ],
#         [
#             2847.0
#         ],
#         [
#             2848.0
#         ],
#         [
#             2849.0
#         ],
#         [
#             2850.0
#         ]
#     ],
#     "scan_values_all": []
# }

# %%
numstds = 2
minIzero = 0.002
image_threshold = 0
hot_pixel = 10

numFiles = 1

json_file = DIR_json + scan_name + "_scan_info.json"
print (json_file)

with open(json_file) as file:
    data = json.load(file)
numFiles = len(data['scan_files'])
#numFiles = 13

print ("Processing",numFiles,"files")

Energy_eV = np.empty(0)

for i in range(0,numFiles):
    filename = str(data['scan_files'][i][0])
    filename = os.path.basename(filename)
    exists = os.path.isfile(DIR + filename.replace("BSREAD","JF02T09V02crop"))
    if not exists:
        print("No such file")
    elif exists and i!=39: #Do we need this 39?
        print("step",i+1,"of",numFiles,": Processing %s" %(str(data['scan_files'][i][0])))

    images, _ = load_JF_cropped_data(DIR + filename.replace("BSREAD","JF02T09V02crop") , 2, nshots=None)
    
    print(DIR + filename.replace("BSREAD","JF02T09V02crop"))
    print(DIRBS + filename)
    
    (_, _, IzeroFEL, _, _, _, Energy, _, _, _ )\
        = load_PumpProbe_events_withTwoVariables(DIRBS + filename, channel_BS_pulse_ids, channel_energy)
    
    total = 0

    IzeroMedian = np.median(IzeroFEL)
    IzeroSTD = np.std(IzeroFEL)
    
    nframes = images.shape[0]

    Energy = [x for x in Energy if (np.abs(x) > 0)]
    Energy_eV = np.append(Energy_eV, np.mean(Energy))

    IzeroMedian = np.median(IzeroFEL)
    IzeroSTD = np.std(IzeroFEL)

    print('number of frames')
    print(nframes)

    images_good = images

    images_thr = images_good.copy()
    images_thr[images_good < image_threshold] = 0
    images_thr[images_good > hot_pixel] = 0
    
    conditionMax = IzeroFEL < IzeroMedian+numstds*IzeroSTD
    conditionMin = IzeroFEL > IzeroMedian-numstds*IzeroSTD
    conditionLow = IzeroFEL > minIzero
    condition = np.logical_and.reduce((conditionLow, conditionMin, conditionMax)).T[0]
    
    images_thr = images_thr[condition]

    print('number of surviving frames')
    print(images_thr.shape[0])

    XES = images_thr.sum(axis=0)
    #/images_thr.shape[0]
    
    print("XES size")
    print(XES.shape)
    
    if i == 10:
        
        plt.figure()
        plt.imshow(XES, vmax = 0.1, vmin = 0)
    
    if i == 0:
        RIXS = XES.sum(axis=0)
    else:
        RIXS = np.vstack((RIXS,XES.sum(axis=0)))

print("RIXS shape")
print(RIXS.shape)
# Out:
# /sf/alvra/data/p17983/res/scan_info/Ru_foil_monoscan_001_scan_info.json
# Processing 21 files
# step 1 of 21 : Processing /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0000.BSREAD.h5
# images_roi2
# <KeysViewHDF5 ['coords_roi1', 'coords_roi2', 'coords_roi3', 'coords_roi4', 'images_roi1', 'images_roi2', 'images_roi3', 'images_roi4', 'pulse_ids']>
# /das/work/p17/p17983/cropped_data/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0000.JF02T09V02crop.h5
# /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0000.BSREAD.h5
# number of frames
# 1000
# number of surviving frames
# 409
# XES size
# (512, 300)
# step 2 of 21 : Processing /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0001.BSREAD.h5
# images_roi2
# <KeysViewHDF5 ['coords_roi1', 'coords_roi2', 'coords_roi3', 'coords_roi4', 'images_roi1', 'images_roi2', 'images_roi3', 'images_roi4', 'pulse_ids']>
# /das/work/p17/p17983/cropped_data/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0001.JF02T09V02crop.h5
# /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0001.BSREAD.h5
# number of frames
# 1000
# number of surviving frames
# 412
# XES size
# (512, 300)
# step 3 of 21 : Processing /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0002.BSREAD.h5
# images_roi2
# <KeysViewHDF5 ['coords_roi1', 'coords_roi2', 'coords_roi3', 'coords_roi4', 'images_roi1', 'images_roi2', 'images_roi3', 'images_roi4', 'pulse_ids']>
# /das/work/p17/p17983/cropped_data/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0002.JF02T09V02crop.h5
# /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0002.BSREAD.h5
# number of frames
# 1000
# number of surviving frames
# 362
# XES size
# (512, 300)
# step 4 of 21 : Processing /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0003.BSREAD.h5
# images_roi2
# <KeysViewHDF5 ['coords_roi1', 'coords_roi2', 'coords_roi3', 'coords_roi4', 'images_roi1', 'images_roi2', 'images_roi3', 'images_roi4', 'pulse_ids']>
# /das/work/p17/p17983/cropped_data/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0003.JF02T09V02crop.h5
# /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0003.BSREAD.h5
# number of frames
# 1000
# number of surviving frames
# 414
# XES size
# (512, 300)
# step 5 of 21 : Processing /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0004.BSREAD.h5
# images_roi2
# <KeysViewHDF5 ['coords_roi1', 'coords_roi2', 'coords_roi3', 'coords_roi4', 'images_roi1', 'images_roi2', 'images_roi3', 'images_roi4', 'pulse_ids']>
# /das/work/p17/p17983/cropped_data/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0004.JF02T09V02crop.h5
# /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0004.BSREAD.h5
# number of frames
# 1000
# number of surviving frames
# 420
# XES size
# (512, 300)
# step 6 of 21 : Processing /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0005.BSREAD.h5
# images_roi2
# <KeysViewHDF5 ['coords_roi1', 'coords_roi2', 'coords_roi3', 'coords_roi4', 'images_roi1', 'images_roi2', 'images_roi3', 'images_roi4', 'pulse_ids']>
# /das/work/p17/p17983/cropped_data/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0005.JF02T09V02crop.h5
# /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0005.BSREAD.h5
# number of frames
# 1000
# number of surviving frames
# 418
# XES size
# (512, 300)
# step 7 of 21 : Processing /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0006.BSREAD.h5
# images_roi2
# <KeysViewHDF5 ['coords_roi1', 'coords_roi2', 'coords_roi3', 'coords_roi4', 'images_roi1', 'images_roi2', 'images_roi3', 'images_roi4', 'pulse_ids']>
# /das/work/p17/p17983/cropped_data/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0006.JF02T09V02crop.h5
# /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0006.BSREAD.h5
# number of frames
# 1000
# number of surviving frames
# 484
# XES size
# (512, 300)
# step 8 of 21 : Processing /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0007.BSREAD.h5
# images_roi2
# <KeysViewHDF5 ['coords_roi1', 'coords_roi2', 'coords_roi3', 'coords_roi4', 'images_roi1', 'images_roi2', 'images_roi3', 'images_roi4', 'pulse_ids']>
# /das/work/p17/p17983/cropped_data/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0007.JF02T09V02crop.h5
# /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0007.BSREAD.h5
# number of frames
# 1000
# number of surviving frames
# 502
# XES size
# (512, 300)
# step 9 of 21 : Processing /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0008.BSREAD.h5
# images_roi2
# <KeysViewHDF5 ['coords_roi1', 'coords_roi2', 'coords_roi3', 'coords_roi4', 'images_roi1', 'images_roi2', 'images_roi3', 'images_roi4', 'pulse_ids']>
# /das/work/p17/p17983/cropped_data/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0008.JF02T09V02crop.h5
# /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0008.BSREAD.h5
# number of frames
# 1000
# number of surviving frames
# 410
# XES size
# (512, 300)
# step 10 of 21 : Processing /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0009.BSREAD.h5
# images_roi2
# <KeysViewHDF5 ['coords_roi1', 'coords_roi2', 'coords_roi3', 'coords_roi4', 'images_roi1', 'images_roi2', 'images_roi3', 'images_roi4', 'pulse_ids']>
# /das/work/p17/p17983/cropped_data/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0009.JF02T09V02crop.h5
# /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0009.BSREAD.h5
# number of frames
# 1000
# number of surviving frames
# 414
# XES size
# (512, 300)
# step 11 of 21 : Processing /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0010.BSREAD.h5
# images_roi2
# <KeysViewHDF5 ['coords_roi1', 'coords_roi2', 'coords_roi3', 'coords_roi4', 'images_roi1', 'images_roi2', 'images_roi3', 'images_roi4', 'pulse_ids']>
# /das/work/p17/p17983/cropped_data/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0010.JF02T09V02crop.h5
# /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0010.BSREAD.h5
# number of frames
# 1000
# number of surviving frames
# 489
# XES size
# (512, 300)
# <img src="data:image/png;base64,..." width="640">
# step 12 of 21 : Processing /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0011.BSREAD.h5
# images_roi2
# <KeysViewHDF5 ['coords_roi1', 'coords_roi2', 'coords_roi3', 'coords_roi4', 'images_roi1', 'images_roi2', 'images_roi3', 'images_roi4', 'pulse_ids']>
# /das/work/p17/p17983/cropped_data/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0011.JF02T09V02crop.h5
# /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0011.BSREAD.h5
# number of frames
# 1000
# number of surviving frames
# 404
# XES size
# (512, 300)
# step 13 of 21 : Processing /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0012.BSREAD.h5
# images_roi2
# <KeysViewHDF5 ['coords_roi1', 'coords_roi2', 'coords_roi3', 'coords_roi4', 'images_roi1', 'images_roi2', 'images_roi3', 'images_roi4', 'pulse_ids']>
# /das/work/p17/p17983/cropped_data/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0012.JF02T09V02crop.h5
# /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0012.BSREAD.h5
# number of frames
# 1000
# number of surviving frames
# 442
# XES size
# (512, 300)
# step 14 of 21 : Processing /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0013.BSREAD.h5
# images_roi2
# <KeysViewHDF5 ['coords_roi1', 'coords_roi2', 'coords_roi3', 'coords_roi4', 'images_roi1', 'images_roi2', 'images_roi3', 'images_roi4', 'pulse_ids']>
# /das/work/p17/p17983/cropped_data/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0013.JF02T09V02crop.h5
# /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0013.BSREAD.h5
# number of frames
# 1000
# number of surviving frames
# 509
# XES size
# (512, 300)
# step 15 of 21 : Processing /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0014.BSREAD.h5
# images_roi2
# <KeysViewHDF5 ['coords_roi1', 'coords_roi2', 'coords_roi3', 'coords_roi4', 'images_roi1', 'images_roi2', 'images_roi3', 'images_roi4', 'pulse_ids']>
# /das/work/p17/p17983/cropped_data/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0014.JF02T09V02crop.h5
# /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0014.BSREAD.h5
# number of frames
# 1000
# number of surviving frames
# 473
# XES size
# (512, 300)
# step 16 of 21 : Processing /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0015.BSREAD.h5
# images_roi2
# <KeysViewHDF5 ['coords_roi1', 'coords_roi2', 'coords_roi3', 'coords_roi4', 'images_roi1', 'images_roi2', 'images_roi3', 'images_roi4', 'pulse_ids']>
# /das/work/p17/p17983/cropped_data/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0015.JF02T09V02crop.h5
# /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0015.BSREAD.h5
# number of frames
# 1000
# number of surviving frames
# 589
# XES size
# (512, 300)
# step 17 of 21 : Processing /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0016.BSREAD.h5
# images_roi2
# <KeysViewHDF5 ['coords_roi1', 'coords_roi2', 'coords_roi3', 'coords_roi4', 'images_roi1', 'images_roi2', 'images_roi3', 'images_roi4', 'pulse_ids']>
# /das/work/p17/p17983/cropped_data/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0016.JF02T09V02crop.h5
# /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0016.BSREAD.h5
# number of frames
# 1000
# number of surviving frames
# 651
# XES size
# (512, 300)
# step 18 of 21 : Processing /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0017.BSREAD.h5
# images_roi2
# <KeysViewHDF5 ['coords_roi1', 'coords_roi2', 'coords_roi3', 'coords_roi4', 'images_roi1', 'images_roi2', 'images_roi3', 'images_roi4', 'pulse_ids']>
# /das/work/p17/p17983/cropped_data/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0017.JF02T09V02crop.h5
# /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0017.BSREAD.h5
# number of frames
# 1000
# number of surviving frames
# 614
# XES size
# (512, 300)
# step 19 of 21 : Processing /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0018.BSREAD.h5
# images_roi2
# <KeysViewHDF5 ['coords_roi1', 'coords_roi2', 'coords_roi3', 'coords_roi4', 'images_roi1', 'images_roi2', 'images_roi3', 'images_roi4', 'pulse_ids']>
# /das/work/p17/p17983/cropped_data/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0018.JF02T09V02crop.h5
# /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0018.BSREAD.h5
# number of frames
# 1000
# number of surviving frames
# 563
# XES size
# (512, 300)
# step 20 of 21 : Processing /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0019.BSREAD.h5
# images_roi2
# <KeysViewHDF5 ['coords_roi1', 'coords_roi2', 'coords_roi3', 'coords_roi4', 'images_roi1', 'images_roi2', 'images_roi3', 'images_roi4', 'pulse_ids']>
# /das/work/p17/p17983/cropped_data/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0019.JF02T09V02crop.h5
# /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0019.BSREAD.h5
# number of frames
# 1000
# number of surviving frames
# 495
# XES size
# (512, 300)
# step 21 of 21 : Processing /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0020.BSREAD.h5
# images_roi2
# <KeysViewHDF5 ['coords_roi1', 'coords_roi2', 'coords_roi3', 'coords_roi4', 'images_roi1', 'images_roi2', 'images_roi3', 'images_roi4', 'pulse_ids']>
# /das/work/p17/p17983/cropped_data/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0020.JF02T09V02crop.h5
# /sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0020.BSREAD.h5
# number of frames
# 1000
# number of surviving frames
# 608
# XES size
# (512, 300)
# RIXS shape
# (21, 300)

# %%
import jungfrau_utils as ju
with ju.File('/sf/alvra/data/p17983/raw/scan_data/Ru_foil_monoscan_001/Ru_foil_monoscan_001_step0013.JF02T09V02.h5') as jf:
    _sum = 0
    for i in range(100):
        test = jf[i, :, 4950:5250]
        _sum += test
    _sum /= 100

# %%
plt.figure()
plt.imshow(_sum, vmax=0.5, vmin=-0.5, origin='bottom')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.imshow(XES, vmax = 100, vmin = 0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.linspace(0,RIXS.shape[1],RIXS.shape[1]+1)

X,Y = np.meshgrid(np.linspace(0,RIXS.shape[1],RIXS.shape[1]+1),Energy_eV)
plt.figure()
plt.pcolor(X,Y,RIXS)
plt.colorbar()
plt.xlabel('JF pixel')
plt.ylabel('Mono Energy (eV)')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Mono Energy (eV)')

# %%
plt.figure()
plt.plot(sum(RIXS))
plt.xlabel('JF pixel')
plt.title('XES')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'XES')

# %%
plt.figure()
plt.plot(Energy_eV, RIXS.sum(axis=1))
plt.xlabel('Mono Energy')
plt.title('XES sum')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'XES sum')
